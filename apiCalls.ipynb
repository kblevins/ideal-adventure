# %%
import json
import requests

# %%
target_url = "https://ebird.org/ws2.0/data/obs/US/recent"
header = {"x-ebirdapitoken": "p54pcbn15ebh"}

# %%
recent_response = requests.get(target_url, headers=header)

# %%
recent_response.json()
# Out:
# [{'comName': 'Carolina Chickadee',
#   'howMany': 2,
#   'lat': 33.901624,
#   'lng': -84.1292667,
#   'locId': 'L6836186',
#   'locName': 'A',
#   'locationPrivate': True,
#   'obsDt': '2018-02-18 08:23',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Poecile carolinensis',
#   'speciesCode': 'carchi'},
#  {'comName': 'White-breasted Nuthatch',
#   'howMany': 1,
#   'lat': 33.901624,
#   'lng': -84.1292667,
#   'locId': 'L6836186',
#   'locName': 'A',
#   'locationPrivate': True,
#   'obsDt': '2018-02-18 08:23',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Sitta carolinensis',
#   'speciesCode': 'whbnut'},
#  {'comName': 'Tufted Titmouse',
#   'howMany': 1,
#   'lat': 33.901624,
#   'lng': -84.1292667,
#   'locId': 'L6836186',
#   'locName': 'A',
#   'locationPrivate': True,
#   'obsDt': '2018-02-18 08:23',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Baeolophus bicolor',
#   'speciesCode': 'tuftit'},
# ...

# %% [markdown]
# # Sightings for last 10 years in US

# %%
##set up params variables

rank = "mrec"
detail = "full"
cat = "species"

# %%
# url = "https://ebird.org/ws2.0/data/obs/US/historic/2007/12/31?"

url = "https://ebird.org/ws2.0/data/obs/US/historic/2012/12/16?rank=mrec&detail=full&cat=species&checklistSort=false&maxResults=100"

header = {"x-ebirdapitoken": "p54pcbn15ebh"}

# #params = {
#     "rank": rank,
#     "detail": detail,
#     "cat": cat
# }

# %%
url
# Out:
# 'https://ebird.org/ws2.0/data/obs/US/historic/2012/12/16?rank=mrec&detail=full&cat=species&checklistSort=false&maxResults=100'

# %%
historic_response = requests.get(url, headers=header)

# %%
historic_response.json()
# Out:
# {'errors': [{'code': 'http.status.500',
#    'status': '500',
#    'title': 'PreparedStatementCallback; SQL  ORA-01013: user requested cancel of current operation\n; nested exception is java.sql.SQLTimeoutException: ORA-01013: user requested cancel of current operation\n'}]}

# %% [markdown]
# # Recent Austin Birds

# %%
recent_url = "https://ebird.org/ws2.0/data/obs/geo/recent?lat=30.2672&lng=-97.7431"

header = {"x-ebirdapitoken": "p54pcbn15ebh"}

# %%
local_response = requests.get(recent_url, headers=header)

# %%
local_response.json()
# Out:
# [{'comName': 'White-winged Dove',
#   'howMany': 1,
#   'lat': 30.415291,
#   'lng': -97.716168,
#   'locId': 'L2629532',
#   'locName': 'Home - Walnut Crossing',
#   'locationPrivate': True,
#   'obsDt': '2018-02-17 08:38',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Zenaida asiatica',
#   'speciesCode': 'whwdov'},
#  {'comName': 'Blue Jay',
#   'howMany': 3,
#   'lat': 30.415291,
#   'lng': -97.716168,
#   'locId': 'L2629532',
#   'locName': 'Home - Walnut Crossing',
#   'locationPrivate': True,
#   'obsDt': '2018-02-17 08:38',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Cyanocitta cristata',
#   'speciesCode': 'blujay'},
#  {'comName': 'American Robin',
#   'howMany': 24,
#   'lat': 30.4154625,
#   'lng': -97.716184,
#   'locId': 'L2947087',
#   'locName': 'Ambleside Drive',
#   'locationPrivate': True,
#   'obsDt': '2018-02-17 08:38',
#   'obsReviewed': False,
#   'obsValid': True,
#   'sciName': 'Turdus migratorius',
# ...

# %% [markdown]
# # Species List

# %%
# CIENTIFIC_NAME,COMMON_NAME,SPECIES_CODE,CATEGORY,TAXON_ORDER,COM_NAME_CODES,SCI_NAME_CODES,BANDING_CODES,ORDER,FAMILY_COM_NAME,FAMILY_SCI_NAME,REPORT_AS,EXTINCT,EXTINCT_YEAR
# Struthio camelus,Common Ostrich,ostric2,species,3.0,COOS,STCA,,Struthioniformes,Ostriches,Struthionidae,,,
# Struthio molybdophanes,Somali Ostrich,ostric3,species,5.0,SOOS,STMO,,Struthioniformes,Ostriches,Struthionidae,,,
# Struthio camelus/molybdophanes,Common/Somali Ostrich,y00934,slash,6.0,SOOS COOS,STCA STMO,,Struthioniformes,Ostriches,Struthionidae,,,
# Rhea americana,Greater Rhea,grerhe1,species,7.0,GRRH,RHAM,,Rheiformes,Rheas,Rheidae,,,
# Rhea pennata,Lesser Rhea,lesrhe2,species,13.0,LERH,RHPE,,Rheiformes,Rheas,Rheidae,,,
# Rhea pennata tarapacensis/garle

# %%
species_url = "https://ebird.org/ws2.0/data/obs/US/recent/cangoo"

header = {"x-ebirdapitoken": "p54pcbn15ebh"}

# %%
local_response = requests.get(species_url, headers=header)

# %%
goose = local_response.json()

# %%
goose[0]
# Out:
# {'comName': 'Canada Goose',
#  'howMany': 2,
#  'lat': 38.0660005,
#  'lng': -78.4798425,
#  'locId': 'L6533546',
#  'locName': 'Brookmill',
#  'locationPrivate': True,
#  'obsDt': '2018-02-21 23:57',
#  'obsReviewed': False,
#  'obsValid': True,
#  'sciName': 'Branta canadensis',
#  'speciesCode': 'cangoo'}

# %%
for geese in goose
